# %%
import pandas as pd
import time
import numpy as np
from matplotlib import pyplot
from pandas import Series, DataFrame, Panel
# %pylab inline
series = Series.from_csv('aat1.csv', header =0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# series.head()

# %%
series.shape
# Out:
# (71,)

# %%
series.plot()

# %%
series['1941':'1947'].plot()# Plot showing the lowest employment/year

# %%
series['1990':'1996'].plot()# Plot showing the rise in employment & year

# %%
series.iloc[6:]
# Out:
# Year
# 1947-01-01    106018
# 1947-01-01    101827
# 1948-01-01    103068
# 1949-01-01    103994
# 1950-01-01    104995
# 1951-01-01    104621
# 1952-01-01    105231
# 1953-01-01    107056
# 1954-01-01    108321
# 1955-01-01    109683
# 1956-01-01    110954
# 1957-01-01    112265
# 1958-01-01    113727
# 1959-01-01    115329
# 1960-01-01    117245
# 1961-01-01    118771
# 1962-01-01    120153
# 1963-01-01    122416
# 1964-01-01    124485
# 1965-01-01    126513
# 1966-01-01    128058
# 1967-01-01    129874
# 1968-01-01    132028
# 1969-01-01    134335
# 1970-01-01    137085
# 1971-01-01    140216
# 1972-01-01    144126
# 1973-01-01    147096
# 1974-01-01    150120
# 1975-01-01    153153
#                ...
# 1981-01-01    170130
# 1982-01-01    172271
# 1983-01-01    174215
# 1984-01-01    176383
# 1985-01-01    178206
# 1986-01-01    180587
# 1987-01-01    182753
# 1988-01-01    184613
# 1989-01-01    186393
# 1990-01-01    189164
# 1991-01-01    190925
# 1992-01-01    192805
# ...

# %%
series.tail()
# Out:
# Year
# 2006-01-01    228815
# 2007-01-01    231867
# 2008-01-01    233788
# 2009-01-01    235801
# 2010-01-01    237830
# Name: Civilian noninstitutional population, dtype: int64
